# %%
import numpy as np
import pandas as pd
import sapdi
from pmdarima.arima import auto_arima
np.random.seed(20)
ws = sapdi.get_workspace(name='covid_connection')
dc = ws.get_datacollection(name='datasets')
with dc.open('GCP_IN_data.csv').get_reader() as reader:
    df_all_states = pd.read_csv(reader)

# %%
# pip install pmdarima

# %%
df_all_states.Date = [x[2:] for x in df_all_states.Date]
df_all_states.Date = pd.to_datetime(df_all_states.Date,dayfirst=True)
kerala = df_all_states[df_all_states['State/UnionTerritory']=='Kerala']
karnataka = df_all_states[df_all_states['State/UnionTerritory']=='Karnataka']
Maharashtra = df_all_states[df_all_states['State/UnionTerritory']=='Maharashtra']

# %%
# Maharashtra.set_index('Date',inplace=True)

# Maharashtra_deaths = Maharashtra[['Deaths']]

# mh_deaths_log = np.log(Maharashtra_deaths.Deaths + 1)

# from pmdarima.arima import auto_arima
# stepwise_model = auto_arima(mh_deaths_log, start_p=0, start_q=0, max_p=4, max_q=4, trace=True,
#                            error_action='ignore',
#                             seasonal=False,
#                            suppress_warnings=True,stepwise=False, out_of_sample_size =3,
#                            information_criterion='oob')
# stepwise_model.fit(mh_deaths_log)
# future_forecast = stepwise_model.predict(n_periods=10)



# np.expm1(future_forecast)

# np.expm1(5.993961)

# %%
def generate_future_timestamps(df,num_prediction):
    last_date = df.index[-1]
    prediction_dates = pd.date_range(last_date,freq='D', periods=num_prediction+1).tolist()
    return prediction_dates

# %%
final_forecasts = pd.DataFrame()
forecast_dates = generate_future_timestamps(df_all_states.set_index('Date'),10)
for state in [karnataka,Maharashtra]:
    state_name = state.iloc[1]['State/UnionTerritory']
    print(f'processing for state : {state_name}')
    
    df_forecast = pd.DataFrame()
    df_forecast['Date'] = forecast_dates[1:]
    df_forecast['State/UnionTerritory'] = state_name
    
    for column in ['Cured','Deaths','Confirmed']:
        
        print(f'Forecasting for {state_name} -- {column}:')
        temp_cases_df = state[['Date',column]]
        temp_cases_df = temp_cases_df.set_index("Date")
        temp_cases_log = np.log(temp_cases_df[column] + 1)
        
        
        stepwise_model = auto_arima(temp_cases_log, start_p=0, start_q=0, max_p=4, max_q=4, trace=True,
                           error_action='ignore',
                            seasonal=False,
                           suppress_warnings=True,stepwise=False, out_of_sample_size =3,
                           information_criterion='oob')
        stepwise_model.fit(temp_cases_log)
        df_forecast[column] = np.expm1(stepwise_model.predict(n_periods=10))
        
#     print( df_forecast.head())   
    final_forecasts = pd.concat([final_forecasts,df_forecast])
# Out:
# processing for state : Karnataka
# Forecasting for Karnataka -- Cured:
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=True]; AIC=-34.084, BIC=-30.221, Time=0.092 seconds
# Fit ARIMA(0,1,1)x(0,0,0,0) [intercept=True]; AIC=-34.611, BIC=-28.816, Time=0.393 seconds
# Fit ARIMA(0,1,2)x(0,0,0,0) [intercept=True]; AIC=-33.799, BIC=-26.072, Time=0.409 seconds
# Fit ARIMA(0,1,3)x(0,0,0,0) [intercept=True]; AIC=-31.798, BIC=-22.139, Time=1.091 seconds
# Fit ARIMA(0,1,4)x(0,0,0,0) [intercept=True]; AIC=-29.816, BIC=-18.225, Time=1.902 seconds
# Fit ARIMA(1,1,0)x(0,0,0,0) [intercept=True]; AIC=-35.216, BIC=-29.420, Time=0.221 seconds
# Fit ARIMA(1,1,1)x(0,0,0,0) [intercept=True]; AIC=-33.511, BIC=-25.784, Time=0.394 seconds
# Fit ARIMA(1,1,2)x(0,0,0,0) [intercept=True]; AIC=-31.798, BIC=-22.139, Time=0.793 seconds
# Fit ARIMA(1,1,3)x(0,0,0,0) [intercept=True]; AIC=-30.156, BIC=-18.565, Time=2.193 seconds
# Fit ARIMA(1,1,4)x(0,0,0,0) [intercept=True]; AIC=-28.202, BIC=-14.679, Time=2.996 seconds
# Fit ARIMA(2,1,0)x(0,0,0,0) [intercept=True]; AIC=-33.603, BIC=-25.876, Time=0.401 seconds
# Fit ARIMA(2,1,1)x(0,0,0,0) [intercept=True]; AIC=-31.699, BIC=-22.040, Time=0.506 seconds
# Fit ARIMA(2,1,2)x(0,0,0,0) [intercept=True]; AIC=-33.982, BIC=-22.391, Time=1.397 seconds
# Fit ARIMA(2,1,3)x(0,0,0,0) [intercept=True]; AIC=-32.257, BIC=-18.735, Time=2.492 seconds
# Fit ARIMA(3,1,0)x(0,0,0,0) [intercept=True]; AIC=-31.725, BIC=-22.066, Time=0.513 seconds
# Fit ARIMA(3,1,1)x(0,0,0,0) [intercept=True]; AIC=-29.736, BIC=-18.145, Time=0.697 seconds
# Fit ARIMA(3,1,2)x(0,0,0,0) [intercept=True]; AIC=-32.188, BIC=-18.665, Time=2.502 seconds
# Fit ARIMA(4,1,0)x(0,0,0,0) [intercept=True]; AIC=-29.783, BIC=-18.192, Time=1.491 seconds
# Fit ARIMA(4,1,1)x(0,0,0,0) [intercept=True]; AIC=-28.204, BIC=-14.682, Time=3.401 seconds
# Total fit time: 23.892 seconds
# Forecasting for Karnataka -- Deaths:
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=True]; AIC=-58.688, BIC=-54.824, Time=0.104 seconds
# Fit ARIMA(0,1,1)x(0,0,0,0) [intercept=True]; AIC=-56.912, BIC=-51.116, Time=0.215 seconds
# Fit ARIMA(0,1,2)x(0,0,0,0) [intercept=True]; AIC=-56.314, BIC=-48.586, Time=0.490 seconds
# Fit ARIMA(0,1,3)x(0,0,0,0) [intercept=True]; AIC=-54.533, BIC=-44.874, Time=1.786 seconds
# Fit ARIMA(0,1,4)x(0,0,0,0) [intercept=True]; AIC=-55.175, BIC=-43.584, Time=2.706 seconds
# Fit ARIMA(1,1,0)x(0,0,0,0) [intercept=True]; AIC=-56.842, BIC=-51.047, Time=0.228 seconds
# Fit ARIMA(1,1,1)x(0,0,0,0) [intercept=True]; AIC=-59.977, BIC=-52.250, Time=0.676 seconds
# Fit ARIMA(1,1,2)x(0,0,0,0) [intercept=True]; AIC=-58.357, BIC=-48.698, Time=1.891 seconds
# Fit ARIMA(1,1,3)x(0,0,0,0) [intercept=True]; AIC=-55.960, BIC=-44.369, Time=2.300 seconds
# Fit ARIMA(1,1,4)x(0,0,0,0) [intercept=True]; AIC=-53.474, BIC=-39.951, Time=4.400 seconds
# Fit ARIMA(2,1,0)x(0,0,0,0) [intercept=True]; AIC=-56.023, BIC=-48.296, Time=0.397 seconds
# Fit ARIMA(2,1,1)x(0,0,0,0) [intercept=True]; AIC=-58.301, BIC=-48.642, Time=0.716 seconds
# Fit ARIMA(2,1,2)x(0,0,0,0) [intercept=True]; AIC=-57.350, BIC=-45.759, Time=1.394 seconds
# Fit ARIMA(2,1,3)x(0,0,0,0) [intercept=True]; AIC=-50.512, BIC=-36.989, Time=3.295 seconds
# Fit ARIMA(3,1,0)x(0,0,0,0) [intercept=True]; AIC=-54.338, BIC=-44.679, Time=0.601 seconds
# Fit ARIMA(3,1,1)x(0,0,0,0) [intercept=True]; AIC=-56.197, BIC=-44.606, Time=1.497 seconds
# Fit ARIMA(3,1,2)x(0,0,0,0) [intercept=True]; AIC=-54.534, BIC=-41.012, Time=1.704 seconds
# Fit ARIMA(4,1,0)x(0,0,0,0) [intercept=True]; AIC=-52.465, BIC=-40.874, Time=2.197 seconds
# Fit ARIMA(4,1,1)x(0,0,0,0) [intercept=True]; AIC=-52.305, BIC=-38.782, Time=4.198 seconds
# Total fit time: 30.802 seconds
# Forecasting for Karnataka -- Confirmed:
# Fit ARIMA(0,2,0)x(0,0,0,0) [intercept=True]; AIC=-4.186, BIC=-0.362, Time=0.022 seconds
# Fit ARIMA(0,2,1)x(0,0,0,0) [intercept=True]; AIC=-34.334, BIC=-28.598, Time=0.361 seconds
# Fit ARIMA(0,2,2)x(0,0,0,0) [intercept=True]; AIC=-42.688, BIC=-35.040, Time=1.302 seconds
# Fit ARIMA(0,2,3)x(0,0,0,0) [intercept=True]; AIC=-30.810, BIC=-21.249, Time=3.003 seconds
# Fit ARIMA(0,2,4)x(0,0,0,0) [intercept=True]; AIC=-39.799, BIC=-28.327, Time=3.600 seconds
# Fit ARIMA(1,2,0)x(0,0,0,0) [intercept=True]; AIC=-12.629, BIC=-6.893, Time=0.309 seconds
# Fit ARIMA(1,2,1)x(0,0,0,0) [intercept=True]; AIC=-37.277, BIC=-29.629, Time=0.585 seconds
# Fit ARIMA(1,2,2)x(0,0,0,0) [intercept=True]; AIC=-32.342, BIC=-22.782, Time=1.305 seconds
# Fit ARIMA(1,2,3)x(0,0,0,0) [intercept=True]; AIC=-41.891, BIC=-30.419, Time=4.400 seconds
# Fit ARIMA(1,2,4)x(0,0,0,0) [intercept=True]; AIC=-40.220, BIC=-26.836, Time=3.400 seconds
# Fit ARIMA(2,2,0)x(0,0,0,0) [intercept=True]; AIC=-28.085, BIC=-20.437, Time=0.411 seconds
# Fit ARIMA(2,2,1)x(0,0,0,0) [intercept=True]; AIC=-42.743, BIC=-33.183, Time=0.694 seconds
# Fit ARIMA(2,2,2)x(0,0,0,0) [intercept=True]; AIC=-40.821, BIC=-29.348, Time=1.398 seconds
# Fit ARIMA(2,2,3)x(0,0,0,0) [intercept=True]; AIC=-40.770, BIC=-27.386, Time=3.299 seconds
# Fit ARIMA(3,2,0)x(0,0,0,0) [intercept=True]; AIC=-31.256, BIC=-21.695, Time=0.803 seconds
# Fit ARIMA(3,2,1)x(0,0,0,0) [intercept=True]; AIC=-40.785, BIC=-29.313, Time=1.701 seconds
# Fit ARIMA(3,2,2)x(0,0,0,0) [intercept=True]; AIC=-41.083, BIC=-27.698, Time=1.910 seconds
# Fit ARIMA(4,2,0)x(0,0,0,0) [intercept=True]; AIC=-30.722, BIC=-19.250, Time=1.997 seconds
# Fit ARIMA(4,2,1)x(0,0,0,0) [intercept=True]; AIC=-38.374, BIC=-24.990, Time=2.710 seconds
# Total fit time: 33.394 seconds
# processing for state : Maharashtra
# Forecasting for Maharashtra -- Cured:
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=True]; AIC=30.542, BIC=34.406, Time=0.104 seconds
# Fit ARIMA(0,1,1)x(0,0,0,0) [intercept=True]; AIC=32.291, BIC=38.087, Time=0.196 seconds
# Fit ARIMA(0,1,2)x(0,0,0,0) [intercept=True]; AIC=32.575, BIC=40.302, Time=0.482 seconds
# Fit ARIMA(0,1,3)x(0,0,0,0) [intercept=True]; AIC=34.542, BIC=44.201, Time=0.703 seconds
# Fit ARIMA(0,1,4)x(0,0,0,0) [intercept=True]; AIC=36.357, BIC=47.948, Time=1.102 seconds
# Fit ARIMA(1,1,0)x(0,0,0,0) [intercept=True]; AIC=32.198, BIC=37.993, Time=0.226 seconds
# Fit ARIMA(1,1,1)x(0,0,0,0) [intercept=True]; AIC=33.598, BIC=41.325, Time=0.472 seconds
# Fit ARIMA(1,1,2)x(0,0,0,0) [intercept=True]; AIC=34.521, BIC=44.180, Time=0.506 seconds
# Fit ARIMA(1,1,3)x(0,0,0,0) [intercept=True]; AIC=36.351, BIC=47.942, Time=1.690 seconds
# Fit ARIMA(1,1,4)x(0,0,0,0) [intercept=True]; AIC=38.280, BIC=51.803, Time=2.805 seconds
# Fit ARIMA(2,1,0)x(0,0,0,0) [intercept=True]; AIC=32.477, BIC=40.205, Time=0.409 seconds
# Fit ARIMA(2,1,1)x(0,0,0,0) [intercept=True]; AIC=34.417, BIC=44.076, Time=0.400 seconds
# Fit ARIMA(2,1,2)x(0,0,0,0) [intercept=True]; AIC=36.285, BIC=47.876, Time=1.017 seconds
# Fit ARIMA(2,1,3)x(0,0,0,0) [intercept=True]; AIC=38.898, BIC=52.421, Time=3.170 seconds
# Fit ARIMA(3,1,0)x(0,0,0,0) [intercept=True]; AIC=34.436, BIC=44.095, Time=0.609 seconds
# Fit ARIMA(3,1,1)x(0,0,0,0) [intercept=True]; AIC=36.229, BIC=47.820, Time=1.396 seconds
# Fit ARIMA(3,1,2)x(0,0,0,0) [intercept=True]; AIC=38.220, BIC=51.743, Time=1.397 seconds
# Fit ARIMA(4,1,0)x(0,0,0,0) [intercept=True]; AIC=36.435, BIC=48.026, Time=1.197 seconds
# Fit ARIMA(4,1,1)x(0,0,0,0) [intercept=True]; AIC=38.205, BIC=51.728, Time=4.198 seconds
# Total fit time: 22.088 seconds
# Forecasting for Maharashtra -- Deaths:
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=True]; AIC=-43.071, BIC=-39.207, Time=0.126 seconds
# Fit ARIMA(0,1,1)x(0,0,0,0) [intercept=True]; AIC=-41.776, BIC=-35.981, Time=0.389 seconds
# Fit ARIMA(0,1,2)x(0,0,0,0) [intercept=True]; AIC=-41.850, BIC=-34.123, Time=0.579 seconds
# Fit ARIMA(0,1,3)x(0,0,0,0) [intercept=True]; AIC=-39.851, BIC=-30.192, Time=1.499 seconds
# Fit ARIMA(0,1,4)x(0,0,0,0) [intercept=True]; AIC=-39.749, BIC=-28.158, Time=4.303 seconds
# Fit ARIMA(1,1,0)x(0,0,0,0) [intercept=True]; AIC=-42.082, BIC=-36.287, Time=0.229 seconds
# Fit ARIMA(1,1,1)x(0,0,0,0) [intercept=True]; AIC=-40.965, BIC=-33.237, Time=0.378 seconds
# Fit ARIMA(1,1,2)x(0,0,0,0) [intercept=True]; AIC=-42.456, BIC=-32.797, Time=1.396 seconds
# Fit ARIMA(1,1,3)x(0,0,0,0) [intercept=True]; AIC=-40.509, BIC=-28.918, Time=2.798 seconds
# Fit ARIMA(1,1,4)x(0,0,0,0) [intercept=True]; AIC=-40.704, BIC=-27.181, Time=4.593 seconds
# Fit ARIMA(2,1,0)x(0,0,0,0) [intercept=True]; AIC=-42.176, BIC=-34.448, Time=0.314 seconds
# Fit ARIMA(2,1,1)x(0,0,0,0) [intercept=True]; AIC=-42.183, BIC=-32.523, Time=0.696 seconds
# Fit ARIMA(2,1,2)x(0,0,0,0) [intercept=True]; AIC=-40.643, BIC=-29.052, Time=2.003 seconds
# Fit ARIMA(2,1,3)x(0,0,0,0) [intercept=True]; AIC=-38.501, BIC=-24.978, Time=3.396 seconds
# Fit ARIMA(3,1,0)x(0,0,0,0) [intercept=True]; AIC=-40.614, BIC=-30.955, Time=0.599 seconds
# Fit ARIMA(3,1,1)x(0,0,0,0) [intercept=True]; AIC=-40.202, BIC=-28.611, Time=1.202 seconds
# Fit ARIMA(3,1,2)x(0,0,0,0) [intercept=True]; AIC=-38.183, BIC=-24.660, Time=1.298 seconds
# Fit ARIMA(4,1,0)x(0,0,0,0) [intercept=True]; AIC=-39.181, BIC=-27.590, Time=0.996 seconds
# Fit ARIMA(4,1,1)x(0,0,0,0) [intercept=True]; AIC=-38.760, BIC=-25.237, Time=3.600 seconds
# Total fit time: 30.401 seconds
# Forecasting for Maharashtra -- Confirmed:
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=True]; AIC=11.141, BIC=15.005, Time=0.114 seconds
# Fit ARIMA(0,1,1)x(0,0,0,0) [intercept=True]; AIC=1.513, BIC=7.308, Time=0.190 seconds
# Fit ARIMA(0,1,2)x(0,0,0,0) [intercept=True]; AIC=-15.374, BIC=-7.647, Time=0.602 seconds
# Fit ARIMA(0,1,3)x(0,0,0,0) [intercept=True]; AIC=-13.565, BIC=-3.906, Time=1.394 seconds
# Fit ARIMA(0,1,4)x(0,0,0,0) [intercept=True]; AIC=-14.191, BIC=-2.600, Time=2.894 seconds
# Fit ARIMA(1,1,0)x(0,0,0,0) [intercept=True]; AIC=-3.110, BIC=2.686, Time=0.221 seconds
# Fit ARIMA(1,1,1)x(0,0,0,0) [intercept=True]; AIC=-1.227, BIC=6.500, Time=0.395 seconds
# Fit ARIMA(1,1,2)x(0,0,0,0) [intercept=True]; AIC=-13.486, BIC=-3.827, Time=0.784 seconds
# Fit ARIMA(1,1,3)x(0,0,0,0) [intercept=True]; AIC=-16.924, BIC=-5.333, Time=2.395 seconds
# Fit ARIMA(1,1,4)x(0,0,0,0) [intercept=True]; AIC=-16.067, BIC=-2.544, Time=6.103 seconds
# Fit ARIMA(2,1,0)x(0,0,0,0) [intercept=True]; AIC=-1.410, BIC=6.318, Time=0.416 seconds
# Fit ARIMA(2,1,1)x(0,0,0,0) [intercept=True]; AIC=0.147, BIC=9.806, Time=0.689 seconds
# Fit ARIMA(2,1,2)x(0,0,0,0) [intercept=True]; AIC=-12.849, BIC=-1.258, Time=1.003 seconds
# Fit ARIMA(2,1,3)x(0,0,0,0) [intercept=True]; AIC=-16.886, BIC=-3.363, Time=3.291 seconds
# Fit ARIMA(3,1,0)x(0,0,0,0) [intercept=True]; AIC=-16.849, BIC=-7.190, Time=1.203 seconds
# Fit ARIMA(3,1,1)x(0,0,0,0) [intercept=True]; AIC=-15.813, BIC=-4.222, Time=1.308 seconds
# Fit ARIMA(3,1,2)x(0,0,0,0) [intercept=True]; AIC=-15.041, BIC=-1.518, Time=1.499 seconds
# Fit ARIMA(4,1,0)x(0,0,0,0) [intercept=True]; AIC=-15.802, BIC=-4.211, Time=1.496 seconds
# Fit ARIMA(4,1,1)x(0,0,0,0) [intercept=True]; AIC=-13.884, BIC=-0.361, Time=3.093 seconds
# Total fit time: 29.096 seconds

# %%
final_forecasts['active_cases'] = final_forecasts.Confirmed - (final_forecasts.Cured + final_forecasts.Deaths)

# %%
final_forecasts
# Out:
#         Date State/UnionTerritory        Cured       Deaths     Confirmed  \
# 0 2020-04-30            Karnataka   239.425085    21.291690    536.344735
# 1 2020-05-01            Karnataka   252.765549    22.662830    539.742943
# 2 2020-05-02            Karnataka   291.017168    24.118308    543.650500
# 3 2020-05-03            Karnataka   329.448420    25.663311    543.919349
# 4 2020-05-04            Karnataka   350.124731    27.303346    542.046879
# 5 2020-05-05            Karnataka   395.353063    29.044258    539.220609
# 6 2020-05-06            Karnataka   451.210890    30.892251    534.124603
# 7 2020-05-07            Karnataka   484.701867    32.853913    526.979022
# 8 2020-05-08            Karnataka   539.113640    34.936235    518.403401
# 9 2020-05-09            Karnataka   616.195281    37.146639    508.117356
# 0 2020-04-30          Maharashtra  1605.682258   434.565315  10451.473163
# 1 2020-05-01          Maharashtra  1795.847373   473.224354  11231.531187
# 2 2020-05-02          Maharashtra  2107.947900   516.820744  12728.633123
# 3 2020-05-03          Maharashtra  2378.229365   565.867068  14657.928934
# 4 2020-05-04          Maharashtra  2793.043546   620.903138  16410.692759
# 5 2020-05-05          Maharashtra  3153.129639   682.537898  18991.212342
# 6 2020-05-06          Maharashtra  3700.731020   751.455201  22136.193076
# 7 2020-05-07          Maharashtra  4180.368741   828.420653  25337.288319
# 8 2020-05-08          Maharashtra  4903.342333   914.289527  29609.416115
# 9 2020-05-09          Maharashtra  5542.106627  1010.015796  34701.381822
#
#    active_cases
# 0    275.627960
# 1    264.314563
# 2    228.515023
# 3    188.807618
# 4    164.618802
# 5    114.823288
# 6     52.021462
# 7      9.423242
# 8    -55.646474
# 9   -145.224564
# 0   8411.225590
# 1   8962.459459
# 2  10103.864478
# 3  11713.832500
# 4  12996.746074
# 5  15155.544805
# 6  17684.006855
# 7  20328.498925
# 8  23791.784255
# 9  28149.259399

# %%
final_forecasts['total_beds'] = np.where(final_forecasts['State/UnionTerritory'] == 'Karnataka', 1000 ,20000)
final_forecasts['available_beds'] = final_forecasts.total_beds - final_forecasts.active_cases

# %%
final_forecasts
# Out:
#         Date State/UnionTerritory        Cured       Deaths     Confirmed  \
# 0 2020-04-30            Karnataka   239.425085    21.291690    536.344735
# 1 2020-05-01            Karnataka   252.765549    22.662830    539.742943
# 2 2020-05-02            Karnataka   291.017168    24.118308    543.650500
# 3 2020-05-03            Karnataka   329.448420    25.663311    543.919349
# 4 2020-05-04            Karnataka   350.124731    27.303346    542.046879
# 5 2020-05-05            Karnataka   395.353063    29.044258    539.220609
# 6 2020-05-06            Karnataka   451.210890    30.892251    534.124603
# 7 2020-05-07            Karnataka   484.701867    32.853913    526.979022
# 8 2020-05-08            Karnataka   539.113640    34.936235    518.403401
# 9 2020-05-09            Karnataka   616.195281    37.146639    508.117356
# 0 2020-04-30          Maharashtra  1605.682258   434.565315  10451.473163
# 1 2020-05-01          Maharashtra  1795.847373   473.224354  11231.531187
# 2 2020-05-02          Maharashtra  2107.947900   516.820744  12728.633123
# 3 2020-05-03          Maharashtra  2378.229365   565.867068  14657.928934
# 4 2020-05-04          Maharashtra  2793.043546   620.903138  16410.692759
# 5 2020-05-05          Maharashtra  3153.129639   682.537898  18991.212342
# 6 2020-05-06          Maharashtra  3700.731020   751.455201  22136.193076
# 7 2020-05-07          Maharashtra  4180.368741   828.420653  25337.288319
# 8 2020-05-08          Maharashtra  4903.342333   914.289527  29609.416115
# 9 2020-05-09          Maharashtra  5542.106627  1010.015796  34701.381822
#
#    active_cases  total_beds  available_beds
# 0    275.627960        1000      724.372040
# 1    264.314563        1000      735.685437
# 2    228.515023        1000      771.484977
# 3    188.807618        1000      811.192382
# 4    164.618802        1000      835.381198
# 5    114.823288        1000      885.176712
# 6     52.021462        1000      947.978538
# 7      9.423242        1000      990.576758
# 8    -55.646474        1000     1055.646474
# 9   -145.224564        1000     1145.224564
# 0   8411.225590       20000    11588.774410
# 1   8962.459459       20000    11037.540541
# 2  10103.864478       20000     9896.135522
# 3  11713.832500       20000     8286.167500
# 4  12996.746074       20000     7003.253926
# 5  15155.544805       20000     4844.455195
# 6  17684.006855       20000     2315.993145
# 7  20328.498925       20000     -328.498925
# 8  23791.784255       20000    -3791.784255
# 9  28149.259399       20000    -8149.259399
